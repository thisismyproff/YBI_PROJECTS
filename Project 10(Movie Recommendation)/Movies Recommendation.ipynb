# %% [markdown]
# # Importing libraries and Dataset

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Movies Recommendation.csv')

# %%
df.head()
# Out:
#    Movie_ID      Movie_Title                       Movie_Genre Movie_Language  \
# 0         1       Four Rooms                      Crime Comedy             en
# 1         2        Star Wars  Adventure Action Science Fiction             en
# 2         3     Finding Nemo                  Animation Family             en
# 3         4     Forrest Gump              Comedy Drama Romance             en
# 4         5  American Beauty                             Drama             en
#
#    Movie_Budget  Movie_Popularity Movie_Release_Date  Movie_Revenue  \
# 0       4000000         22.876230         09-12-1995        4300000
# 1      11000000        126.393695         25-05-1977      775398007
# 2      94000000         85.688789         30-05-2003      940335536
# 3      55000000        138.133331         06-07-1994      677945399
# 4      15000000         80.878605         15-09-1999      356296601
#
#    Movie_Runtime  Movie_Vote  ...  \
# 0           98.0         6.5  ...
# 1          121.0         8.1  ...
# 2          100.0         7.6  ...
# 3          142.0         8.2  ...
# 4          122.0         7.9  ...
#
#                                       Movie_Homepage  \
# 0                                                NaN
# 1  http://www.starwars.com/films/star-wars-episod...
# 2              http://movies.disney.com/finding-nemo
# 3                                                NaN
# 4                      http://www.dreamworks.com/ab/
#
#                                       Movie_Keywords  \
# 0          hotel new year's eve witch bet hotel room
# 1        android galaxy hermit death star lightsaber
# 2  father son relationship harbor underwater fish...
# 3  vietnam veteran hippie mentally disabled runni...
# 4  male nudity female nudity adultery midlife cri...
#
#                                       Movie_Overview  \
# 0  It's Ted the Bellhop's first night on the job....
# 1  Princess Leia is captured and held hostage by ...
# 2  Nemo, an adventurous young clownfish, is unexp...
# 3  A man with a low IQ has accomplished great thi...
# 4  Lester Burnham, a depressed suburban father in...
#
#                               Movie_Production_House  \
# 0  [{"name": "Miramax Films", "id": 14}, {"name":...
# 1  [{"name": "Lucasfilm", "id": 1}, {"name": "Twe...
# 2     [{"name": "Pixar Animation Studios", "id": 3}]
# 3          [{"name": "Paramount Pictures", "id": 4}]
# 4  [{"name": "DreamWorks SKG", "id": 27}, {"name"...
#
#                             Movie_Production_Country  \
# 0  [{"iso_3166_1": "US", "name": "United States o...
# 1  [{"iso_3166_1": "US", "name": "United States o...
# 2  [{"iso_3166_1": "US", "name": "United States o...
# 3  [{"iso_3166_1": "US", "name": "United States o...
# 4  [{"iso_3166_1": "US", "name": "United States o...
#
#                       Movie_Spoken_Language  \
# 0  [{"iso_639_1": "en", "name": "English"}]
# 1  [{"iso_639_1": "en", "name": "English"}]
# 2  [{"iso_639_1": "en", "name": "English"}]
# 3  [{"iso_639_1": "en", "name": "English"}]
# 4  [{"iso_639_1": "en", "name": "English"}]
#
#                                        Movie_Tagline  \
# 0  Twelve outrageous guests. Four scandalous requ...
# 1       A long time ago in a galaxy far, far away...
# 2  There are 3.7 trillion fish in the ocean, they...
# 3  The world will never be the same, once you've ...
# 4                                       Look closer.
#
#                                           Movie_Cast  \
# 0  Tim Roth Antonio Banderas Jennifer Beals Madon...
# 1  Mark Hamill Harrison Ford Carrie Fisher Peter ...
# 2  Albert Brooks Ellen DeGeneres Alexander Gould ...
# 3  Tom Hanks Robin Wright Gary Sinise Mykelti Wil...
# 4  Kevin Spacey Annette Bening Thora Birch Wes Be...
#
#                                           Movie_Crew   Movie_Director
# 0  [{'name': 'Allison Anders', 'gender': 1, 'depa...   Allison Anders
# 1  [{'name': 'George Lucas', 'gender': 2, 'depart...     George Lucas
# 2  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...   Andrew Stanton
# 3  [{'name': 'Alan Silvestri', 'gender': 2, 'depa...  Robert Zemeckis
# 4  [{'name': 'Thomas Newman', 'gender': 2, 'depar...       Sam Mendes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4760 entries, 0 to 4759
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Movie_ID                  4760 non-null   int64
#  1   Movie_Title               4760 non-null   object
#  2   Movie_Genre               4760 non-null   object
#  3   Movie_Language            4760 non-null   object
#  4   Movie_Budget              4760 non-null   int64
#  5   Movie_Popularity          4760 non-null   float64
#  6   Movie_Release_Date        4760 non-null   object
#  7   Movie_Revenue             4760 non-null   int64
#  8   Movie_Runtime             4758 non-null   float64
#  9   Movie_Vote                4760 non-null   float64
#  10  Movie_Vote_Count          4760 non-null   int64
#  11  Movie_Homepage            1699 non-null   object
#  12  Movie_Keywords            4373 non-null   object
#  13  Movie_Overview            4757 non-null   object
#  14  Movie_Production_House    4760 non-null   object
#  15  Movie_Production_Country  4760 non-null   object
#  16  Movie_Spoken_Language     4760 non-null   object
#  17  Movie_Tagline             3942 non-null   object
#  18  Movie_Cast                4733 non-null   object
#  19  Movie_Crew                4760 non-null   object
#  20  Movie_Director            4738 non-null   object
# dtypes: float64(3), int64(4), object(14)
# memory usage: 781.1+ KB

# %%
df.dropna()
# Out:
#       Movie_ID                                        Movie_Title  \
# 1            2                                          Star Wars
# 2            3                                       Finding Nemo
# 4            5                                    American Beauty
# 9           10  Pirates of the Caribbean: The Curse of the Bla...
# 10          11                                  Kill Bill: Vol. 1
# ...        ...                                                ...
# 4728      4755                                     Time to Choose
# 4737      4765                                           Bad Moms
# 4743      4772                                       Fight Valley
# 4745      4774                                              Kicks
# 4748      4777                                      The Dog Lover
#
#                            Movie_Genre Movie_Language  Movie_Budget  \
# 1     Adventure Action Science Fiction             en      11000000
# 2                     Animation Family             en      94000000
# 4                                Drama             en      15000000
# 9             Adventure Fantasy Action             en     140000000
# 10                        Action Crime             en      30000000
# ...                                ...            ...           ...
# 4728                       Documentary             en       3500000
# 4737                            Comedy             en      20000000
# 4743                      Action Drama             en      27000000
# 4745                         Adventure             en             0
# 4748                             Drama             en       2000000
#
#       Movie_Popularity Movie_Release_Date  Movie_Revenue  Movie_Runtime  \
# 1           126.393695         25-05-1977      775398007          121.0
# 2            85.688789         30-05-2003      940335536          100.0
# 4            80.878605         15-09-1999      356296601          122.0
# 9           271.972889         09-07-2003      655011224          143.0
# 10           79.754966         10-10-2003      180949000          111.0
# ...                ...                ...            ...            ...
# 4728          1.618138         04-09-2015              0          100.0
# 4737         42.512296         28-07-2016      183936074          100.0
# 4743          1.224105         22-07-2016              0           90.0
# 4745          3.467923         09-09-2016              0           80.0
# 4748          1.193219         08-07-2016              0          101.0
#
#       Movie_Vote  ...                                     Movie_Homepage  \
# 1            8.1  ...  http://www.starwars.com/films/star-wars-episod...
# 2            7.6  ...              http://movies.disney.com/finding-nemo
# 4            7.9  ...                      http://www.dreamworks.com/ab/
# 9            7.5  ...  http://disney.go.com/disneyvideos/liveaction/p...
# 10           7.7  ...   http://www.miramax.com/movie/kill-bill-volume-1/
# ...          ...  ...                                                ...
# 4728         0.0  ...                        http://www.timetochoose.com
# 4737         6.3  ...                      http://stxmovies.com/badmoms/
# 4743         3.9  ...                        http://www.fightvalley.com/
# 4745         7.5  ...                 http://www.focusfeatures.com/kicks
# 4748         5.3  ...                   http://www.thedoglovermovie.com/
#
#                                          Movie_Keywords  \
# 1           android galaxy hermit death star lightsaber
# 2     father son relationship harbor underwater fish...
# 4     male nudity female nudity adultery midlife cri...
# 9     exotic island blacksmith east india trading co...
# 10           japan coma martial arts kung fu underworld
# ...                                                 ...
# 4728                         climate change documentary
# 4737                   alcohol bar party divorce family
# 4743        new jersey martial arts sister sport murder
# 4745  blow job cigarette smoking illegal drugs smoki...
# 4748  undercover dog animal welfare animal rights or...
#
#                                          Movie_Overview  \
# 1     Princess Leia is captured and held hostage by ...
# 2     Nemo, an adventurous young clownfish, is unexp...
# 4     Lester Burnham, a depressed suburban father in...
# 9     Jack Sparrow, a freewheeling 17th-century pira...
# 10    An assassin is shot at the altar by her ruthle...
# ...                                                 ...
# 4728  Academy Award® winning director Charles Fergus...
# 4737  When three overworked and under-appreciated mo...
# 4743  When Tory Coro turns up dead, the neighborhood...
# 4745  When his hard-earned kicks get snatched by a l...
# 4748  Sara Gold is a young girl on a quest to save m...
#
#                                  Movie_Production_House  \
# 1     [{"name": "Lucasfilm", "id": 1}, {"name": "Twe...
# 2        [{"name": "Pixar Animation Studios", "id": 3}]
# 4     [{"name": "DreamWorks SKG", "id": 27}, {"name"...
# 9     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 10    [{"name": "Miramax Films", "id": 14}, {"name":...
# ...                                                 ...
# 4728  [{"name": "Representational Pictures", "id": 8...
# 4737  [{"name": "STX Entertainment", "id": 47729}, {...
# 4743   [{"name": "Cinestyle Media Group", "id": 74413}]
# 4745  [{"name": "Bystorm Films", "id": 2903}, {"name...
# 4748  [{"name": "ESX Productions", "id": 37081}, {"n...
#
#                                Movie_Production_Country  \
# 1     [{"iso_3166_1": "US", "name": "United States o...
# 2     [{"iso_3166_1": "US", "name": "United States o...
# 4     [{"iso_3166_1": "US", "name": "United States o...
# 9     [{"iso_3166_1": "US", "name": "United States o...
# 10    [{"iso_3166_1": "US", "name": "United States o...
# ...                                                 ...
# 4728  [{"iso_3166_1": "US", "name": "United States o...
# 4737  [{"iso_3166_1": "US", "name": "United States o...
# 4743  [{"iso_3166_1": "US", "name": "United States o...
# 4745  [{"iso_3166_1": "US", "name": "United States o...
# 4748  [{"iso_3166_1": "US", "name": "United States o...
#
#                                   Movie_Spoken_Language  \
# 1              [{"iso_639_1": "en", "name": "English"}]
# 2              [{"iso_639_1": "en", "name": "English"}]
# 4              [{"iso_639_1": "en", "name": "English"}]
# 9              [{"iso_639_1": "en", "name": "English"}]
# 10    [{"iso_639_1": "en", "name": "English"}, {"iso...
# ...                                                 ...
# 4728           [{"iso_639_1": "en", "name": "English"}]
# 4737  [{"iso_639_1": "ru", "name": "P\u0443\u0441\u0...
# 4743  [{"iso_639_1": "pt", "name": "Portugu\u00eas"}...
# 4745           [{"iso_639_1": "en", "name": "English"}]
# 4748           [{"iso_639_1": "en", "name": "English"}]
#
#                                           Movie_Tagline  \
# 1          A long time ago in a galaxy far, far away...
# 2     There are 3.7 trillion fish in the ocean, they...
# 4                                          Look closer.
# 9                 Prepare to be blown out of the water.
# 10                                     Go for the kill.
# ...                                                 ...
# 4728                           Climate change for good.
# 4737                               Party like a mother.
# 4743                            One way in. No way out.
# 4745                             They aren't just shoes
# 4748           She ended up on the wrong side of right.
#
#                                              Movie_Cast  \
# 1     Mark Hamill Harrison Ford Carrie Fisher Peter ...
# 2     Albert Brooks Ellen DeGeneres Alexander Gould ...
# 4     Kevin Spacey Annette Bening Thora Birch Wes Be...
# 9     Johnny Depp Geoffrey Rush Orlando Bloom Keira ...
# 10    Uma Thurman Lucy Liu Vivica A. Fox Daryl Hanna...
# ...                                                 ...
# 4728  Oscar Isaac Jane Goodall Jerry Brown Neal Barn...
# 4737  Mila Kunis Kristen Bell Kathryn Hahn Christina...
# 4743  Erin O'Brien Miesha Tate Holly Holm Cristiane ...
# 4745  Mahershala Ali Kofi Siriboe Christopher Meyer ...
# 4748  Allison Paige James Remar Lea Thompson Jayson ...
#
#                                              Movie_Crew     Movie_Director
# 1     [{'name': 'George Lucas', 'gender': 2, 'depart...       George Lucas
# 2     [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton
# 4     [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 9     [{'name': 'Arthur Schmidt', 'gender': 2, 'depa...     Gore Verbinski
# 10    [{'name': 'Robert Rodriguez', 'gender': 0, 'de...  Quentin Tarantino
# ...                                                 ...                ...
# 4728  [{'name': 'Charles Ferguson', 'gender': 2, 'de...   Charles Ferguson
# 4737  [{'name': 'Jon Lucas', 'gender': 2, 'departmen...          Jon Lucas
# 4743  [{'name': 'Michael P. Lucas', 'gender': 0, 'de...           Rob Hawk
# 4745  [{'name': 'Brian Reitzell', 'gender': 2, 'depa...     Justin Tipping
# 4748  [{'name': 'Ali Afshar', 'gender': 2, 'departme...    Alex Ranarivelo
#
# [1421 rows x 21 columns]

# %% [markdown]
# # Feature_Selection

# %%
df_features = df[['Movie_Genre','Movie_Spoken_Language','Movie_Keywords','Movie_Production_Country','Movie_Cast']]

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4760 entries, 0 to 4759
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Movie_Genre               4760 non-null   object
#  1   Movie_Spoken_Language     4760 non-null   object
#  2   Movie_Keywords            4373 non-null   object
#  3   Movie_Production_Country  4760 non-null   object
#  4   Movie_Cast                4733 non-null   object
# dtypes: object(5)
# memory usage: 186.1+ KB

# %%
df_features = df_features.dropna()

# %%
X = df_features['Movie_Genre']+' '+df_features['Movie_Spoken_Language']+' '+df_features['Movie_Keywords']+' '+df_features['Movie_Production_Country']+' '+df_features['Movie_Cast']

# %%
X
# Out:
# 0       Crime Comedy [{"iso_639_1": "en", "name": "Eng...
# 1       Adventure Action Science Fiction [{"iso_639_1"...
# 2       Animation Family [{"iso_639_1": "en", "name": ...
# 3       Comedy Drama Romance [{"iso_639_1": "en", "nam...
# 4       Drama [{"iso_639_1": "en", "name": "English"}]...
#                               ...
# 4751    Horror [{"iso_639_1": "en", "name": "English"}...
# 4752    History Drama War Action [{"iso_639_1": "en", ...
# 4754    Action Adventure Animation Family Fantasy [{"i...
# 4757    Thriller Drama [{"iso_639_1": "en", "name": "E...
# 4759    Documentary [] music actors legendary perfomer...
# Length: 4364, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
X = tfidf.fit_transform(X)

# %%
X
# Out:
# <4364x12947 sparse matrix of type '<class 'numpy.float64'>'
# 	with 135313 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Getting Similarity Score using Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
Similarity_Score = cosine_similarity(X)

# %%
print(Similarity_Score)
Similarity_Score.shape
# Out:
# [[1.         0.01969064 0.01783883 ... 0.1286528  0.02294662 0.00632509]
#  [0.01969064 1.         0.01752695 ... 0.05266349 0.02254544 0.00621451]
#  [0.01783883 0.01752695 1.         ... 0.05338339 0.02042515 0.00563006]
#  ...
#  [0.1286528  0.05266349 0.05338339 ... 1.         0.0284045  0.00804361]
#  [0.02294662 0.02254544 0.02042515 ... 0.0284045  1.         0.00724212]
#  [0.00632509 0.00621451 0.00563006 ... 0.00804361 0.00724212 1.        ]]
# (4364, 4364)

# %% [markdown]
# # Getting Movie name as Input

# %%
Fav_Movie_Name = input('Enter your favourite movie name:')
# Out:
# Enter your favourite movie name:superman

# %%
All_Movies_Title = df['Movie_Title'].tolist()

# %%
import difflib as dl

# %%
Movie_Recommendation =  dl.get_close_matches(Fav_Movie_Name,All_Movies_Title)

# %%
print(Movie_Recommendation)
Close_Match = Movie_Recommendation[0]
# Out:
# ['Superman', 'Superman II', 'Superman III']

# %%
Index_of_Close_Match_Movie = df[df.Movie_Title == Close_Match]['Movie_ID'].values[0]
print(Index_of_Close_Match_Movie)
Recommendation_Score = list(enumerate(Similarity_Score[Index_of_Close_Match_Movie]))
print(Recommendation_Score)
len(Recommendation_Score)
# Out:
# 614
# [(0, 0.020401116433781247), (1, 0.020044434817535654), (2, 0.0181593555308088), (3, 0.023979757098199432), (4, 0.023007203491147963), (5, 0.058069388566351285), (6, 0.0178695866558513), (7, 0.008679201150604894), (8, 0.05197472558716146), (9, 0.018691474239652044), (10, 0.02602629687366162), (11, 0.031140627675134896), (12, 0.02852703773003549), (13, 0.02042078847060626), (14, 0.018247651090785792), (15, 0.02579220666338637), (16, 0.05326877837731897), (17, 0.0270592503719723), (18, 0.030488837306061), (19, 0.024873332544166613), (20, 0.04650290125971606), (21, 0.031245039926335226), (22, 0.011919466851126444), (23, 0.08341325306311001), (24, 0.026003064967774325), (25, 0.03549424624962887), (26, 0.07442536600759528), (27, 0.05689709793041163), (28, 0.02294930058535654), (29, 0.07022821937602798), (30, 0.019977338290593394), (31, 0.034503323949346104), (32, 0.03335578591765926), (33, 0.024192961046354235), (34, 0.02380869893626156), (35, 0.08707223416576379), (36, 0.020681777121886746), (37, 0.021132877623507403), (38, 0.021917221558477917), (39, 0.023045749266975692), (40, 0.02279371117567694), (41, 0.029527477252236645), (42, 0.011951778324406605), (43, 0.027197684027175085), (44, 0.017629110345648364), (45, 0.02099182424610949), (46, 0.023315517239658426), (47, 0.023911814219425488), (48, 0.02797943293061591), (49, 0.026405864037962367), (50, 0.02900724326776799), (51, 0.05164368666734236), (52, 0.022199566370815948), (53, 0.02845056218803397), (54, 0.02223813106899199), (55, 0.022073148793219022), (56, 0.022277510521546032), (57, 0.0059489363985339066), (58, 0.006018038927997175), (59, 0.07022273738416296), (60, 0.026718668412065855), (61, 0.022140612702086847), (62, 0.09169724242116804), (63, 0.02309061595090702), (64, 0.005729660232518394), (65, 0.01887539695213818), (66, 0.027863391027133953), (67, 0.018757656511545266), (68, 0.03157373599099842), (69, 0.02397274451619662), (70, 0.19277042169523773), (71, 0.027877447919359775), (72, 0.01991789247201861), (73, 0.03415961888982481), (74, 0.02127312190829567), (75, 0.017564125366129668), (76, 0.013987906716092551), (77, 0.06757447306862938), (78, 0.023701367739869812), (79, 0.01857218442140775), (80, 0.07818957178557132), (81, 0.07847493056893477), (82, 0.03783163549200192), (83, 0.022357515636169667), (84, 0.04786239539918377), (85, 0.021434907588176292), (86, 0.029894645142745924), (87, 0.0171630084802573), (88, 0.02273134741878983), (89, 0.018009181027971034), (90,